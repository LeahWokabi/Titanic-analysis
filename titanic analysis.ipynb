# %%
#NAME: LEAH MUNJIRU WOKABI
#REG NO: SCT213-C002-0027/2024

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, roc_auc_score

# %%
df = sns.load_dataset("titanic")
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#missing values
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic=df.copy()

# %%
#filling missing values in age with the median
titanic['age'] = titanic['age'].fillna(titanic['age'].median())
titanic=titanic.drop('deck', axis=1)
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
titanic['embarked'] = titanic['embarked'].fillna(titanic['embarked'].mode()[0])
titanic['embark_town'] = titanic['embark_town'].fillna(titanic['embark_town'].mode()[0])
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male  28.0      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Convert Sex to 0 or 1
titanic['sex'] = titanic['sex'].map({'male': 0, 'female': 1})
titanic.head(5)
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

categorical = []  # no categorical columns left
numeric = ['age', 'sex', 'pclass', 'fare']

preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numeric)
])
#Logistic Regression
log_model = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('model', LogisticRegression(max_iter=1000))
])
log_f1 = cross_val_score(log_model, x, y, cv=5, scoring='f1')
print("Logistic Regression Mean F1:", log_f1.mean())
log_model.fit(x, y)
y_pred_log = log_model.predict(x)
print("Classification Report (Logistic Regression):")
print(classification_report(y, y_pred_log))
print("ROC-AUC:", roc_auc_score(y, log_model.predict_proba(x)[:,1]))
# Out:
# Logistic Regression Mean F1: 0.7142484859024221
# Classification Report (Logistic Regression):
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       549
#            1       0.75      0.71      0.73       342
#
#     accuracy                           0.80       891
#    macro avg       0.79      0.78      0.79       891
# weighted avg       0.80      0.80      0.80       891
#
# ROC-AUC: 0.8475058319752021

# %%
#Decision Tree 
dt_model = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('model', DecisionTreeClassifier(max_depth=4, min_samples_split=20, random_state=42))
])

dt_f1 = cross_val_score(dt_model, x, y, cv=5, scoring='f1')
print("Decision Tree Mean F1:", dt_f1.mean())

dt_model.fit(x, y)
y_pred_dt = dt_model.predict(x)


print("Classification Report (Decision Tree):")
print(classification_report(y, y_pred_dt))
print("ROC-AUC:", roc_auc_score(y, dt_model.predict_proba(x)[:,1]))
# Out:
# Decision Tree Mean F1: 0.6963355563555597
# Classification Report (Decision Tree):
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       549
#            1       0.83      0.70      0.76       342
#
#     accuracy                           0.83       891
#    macro avg       0.83      0.80      0.81       891
# weighted avg       0.83      0.83      0.82       891
#
# ROC-AUC: 0.8745965551401271

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(
    data=titanic,
    x='age',
    hue='survived',
    fill=True,
    common_norm=False,
    alpha=0.5
)
plt.title('Age Distribution of Survivors vs Non-Survivors')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(
    data=titanic,
    x='pclass',
    y='survived',
    hue='sex',
)
plt.title('Survival Rate by Sex and Passenger Class')
plt.ylabel('Survival Probability')
plt.xlabel('Passenger Class')
plt.show()

# %%
sns.barplot(x='sex', y='survived', data=titanic)
plt.title("Survival Rate by Gender")
plt.show()

# %%
sns.boxplot(x='survived', y='fare', data=titanic)
plt.title("Fare Distribution by Survival")
plt.show()

# %%
titanic['age_group'] = pd.cut(
    titanic['age'],
    bins=[0, 12, 18, 35, 60, 100],
    labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior']
)
sns.barplot(x='age_group', y='survived', data=titanic)
plt.title("Survival Rate by Age Group")
plt.show()

# %%
sns.histplot(data=titanic, x='age', hue='survived', stat='density', common_norm=False, kde=True)
plt.title("Normalized Age Distribution by Survival")
plt.show()
